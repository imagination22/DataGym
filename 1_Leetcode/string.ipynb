# %%
# %sql
SELECT length('Databricks'),len('databricks'); -- 10

# %%
# %sql
SELECT lower('HELLO'), upper('hello'),initcap('databricks sql') , reverse('abc');

# %%
# %sql
SELECT concat('Data', 'bricks') -- Databricks
, concat('[',"'",'Data','Bricks',"'",']') --[ ' Data  Bricks  '   ]

# %%
# %sql
SELECT concat_ws(',', array('A','B','C')); -- A,B,C

# %%
# %sql
SELECT substr('Databricks', 1, 4); -- Data  , note it doesnot start with 0 .

# %%
# %sql
SELECT left('Databricks', 4);  -- Data
SELECT right('Databricks', 4); -- icks

# %%
# %sql
SELECT position('brick' IN 'Databricks'); -- 5

# %%
# %sql
SELECT lpad('123', 5, '0'),rpad('123',5,'0'),lpad('abc',5,'c'); -- 00123

# %%
# %sql
SELECT replace('Databricks', 'Data', 'Spark'); -- Sparkbricks

# %%
# %sql
SELECT translate('12345', '123', 'abc'); -- abc45

# %%
# %sql
SELECT regexp_replace('abc123', '[0-9]', ''); -- abc

# %%
# %sql
SELECT regexp_extract('abc123', '([0-9]+)', 1); -- 123

# %%
# %sql
SELECT 'abc123' rlike '[0-9]'; -- true

# %%
# %sql
SELECT split('A,B,C', ','); -- ["A","B","C"]

# %%
# %sql
SELECT element_at(split('A,B,C', ','), 2); -- B

# %%
# %sql
SELECT element_at(split('A,B,C', ','), 2); -- B
